# %%
import pandas as pd
import seaborn as sns

# %%
df_data = pd.read_csv("../../process_dataset/examples_0609/4_dataset_procesed.csv")
df_data
# Out:
#       age  t2m_pre_mean_rr  t2m_pre_rmssd  t2m_pre_pns  t2m_pre_mean_hr  \
# 0    75.0             74.8           21.7      -140.00               80
# 1    66.0             95.3           18.8       -54.00               63
# 2    77.0             81.9           17.5      -106.00               73
# 3    73.0             84.6           13.6      -115.00               71
# 4    65.0            129.6           29.8       156.00               46
# ..    ...              ...            ...          ...              ...
# 524  78.0           1187.0           22.2         0.76               51
# 525  67.0            790.0           16.9        -1.28               76
# 526  77.0            814.0           23.8        -0.98               74
# 527  61.0            912.0           16.6        -0.78               66
# 528  69.0           1016.0           16.9        -0.25               59
#
#      t2m_pre_stress  t2m_pre_sns  t2m_pre_sdnn  t2m_pre_hf  t2m_pre_lf  \
# ...

# %%
data_to_corr = df_data.drop(columns=["sex_1", "sex_2"])
corr_data = data_to_corr.corr(method="spearman")

# %%
sns.heatmap(data=corr_data)
# Out:
# <Axes: >

# %%
corr_data
# Out:
#                       age  t2m_pre_mean_rr  t2m_pre_rmssd  t2m_pre_pns  \
# age              1.000000         0.015616      -0.035402     0.003541
# t2m_pre_mean_rr  0.015616         1.000000       0.166238     0.459101
# t2m_pre_rmssd   -0.035402         0.166238       1.000000     0.212141
# t2m_pre_pns      0.003541         0.459101       0.212141     1.000000
# t2m_pre_mean_hr -0.117007        -0.439469      -0.310513    -0.141288
# t2m_pre_stress   0.027095        -0.440976      -0.341405    -0.603202
# t2m_pre_sns      0.058820        -0.416708      -0.173435    -0.874378
# t2m_pre_sdnn    -0.004876        -0.213192       0.597999    -0.245140
# t2m_pre_hf      -0.090394         0.190637       0.643038     0.310646
# t2m_pre_lf      -0.070270         0.193249       0.391913     0.082785
# t2m_pre_vlf     -0.060711         0.247777       0.294634     0.129112
# bp_systolic      0.057910         0.003430       0.054291    -0.012490
# ...

# %%
corr_data_abs = abs(corr_data)
corr_data_abs.describe()
# Out:
#              age  t2m_pre_mean_rr  t2m_pre_rmssd  t2m_pre_pns  \
# count  18.000000        18.000000      18.000000    18.000000
# mean    0.118121         0.229725       0.255899     0.250714
# std     0.224882         0.248796       0.264017     0.295922
# min     0.003541         0.003430       0.006929     0.003541
# 25%     0.029172         0.057407       0.063117     0.067319
# 50%     0.062474         0.178438       0.169836     0.115655
# 75%     0.095513         0.374475       0.333682     0.294270
# max     1.000000         1.000000       1.000000     1.000000
#
#        t2m_pre_mean_hr  t2m_pre_stress  t2m_pre_sns  t2m_pre_sdnn  t2m_pre_hf  \
# count        18.000000       18.000000    18.000000     18.000000   18.000000
# mean          0.182542        0.260997     0.261849      0.236198    0.277533
# std           0.233139        0.283671     0.309053      0.279650    0.276924
# min           0.000771        0.001686     0.014860      0.004876    0.009303
# ...

# %%
df_data.columns
# Out:
# Index(['age', 't2m_pre_mean_rr', 't2m_pre_rmssd', 't2m_pre_pns',
#        't2m_pre_mean_hr', 't2m_pre_stress', 't2m_pre_sns', 't2m_pre_sdnn',
#        't2m_pre_hf', 't2m_pre_lf', 't2m_pre_vlf', 'bp_systolic',
#        'bp_diastolic', 'bp_pam', 'bp_pp', 'weight kg', 'height cm', 'our_imc',
#        'sex_1', 'sex_2'],
#       dtype='object')

# %%
df_data_rr = df_data[['age', 't2m_pre_mean_rr', 'bp_systolic',
       'bp_diastolic', 'bp_pam', 'bp_pp', 'weight kg', 'height cm', 'our_imc',
       'sex_1', 'sex_2']]
df_data_rr.to_csv("../../process_dataset/examples_1009/rr_dataset.csv", index=False)
